# %%
# pip install nbconvert==6.0.0

# %% [markdown]
# ### código no usado de Banregio

# %%
# #importar datetime para manejo de series de tiempo
# from datetime import date

# %% [markdown]
# Para esta variable, debido a que no tenemos una columna con el número de volúmenes vendidos para cada autor ni el número de libros vendidos antes de la fecha de lanzamiento, se asumirá que cada libro vendido tiene un review por lo que tomaremos el total de Reviews como el total de volúmenes vendidos. Asimismo, tomaremos en consideración los días transcurridos desde la fecha de lanzamiento, puesto que se consideraría que el libro continúa vigente hasta el último día de 2019.

# %%
import datetime
end_date = datetime.datetime.now()
start_date = end_date - datetime.timedelta(days=5)
diff_in_days = abs((end_date - start_date).days)
print(diff_in_days)

# %%
# Convertir fecha a formato datetime
data['FechaLanzamiento']= pd.to_datetime(data['FechaLanzamiento'], format="%Y-%m-%d")
#crear dia de hoy
hoy = pd.datetime.now()
#calcular dias transcurridos desde lanzamiento hasta hoy
data["Dias_transcurridos"] = (hoy - data["FechaLanzamiento"]).dt.days
data.info()

# %%
# buscar libros con fecha de lanzamiento fuera de 2009-2019 como se indica en la instrucción.
outdated = data.loc[(data['FechaLanzamiento'] < '2009-01-01')]
outdated

# %%
# https://pbpython.com/categorical-encoding.html

# %%
# #convertir género en data type categoria
# data["Genero"] = data["Genero"].astype('category')
from sklearn.preprocessing import OneHotEncoder

encoder = OneHotEncoder()
encoder_results = encoder.fit_transform(data[["Genero"]])
data = data.join(pd.DataFrame(encoder_results.toarray(), columns=encoder.categories_))

# %%
#remover catagorical variables
data_int = data.drop(['Titulo', 'Autor', 'Genero'], axis=1)
#plot boxplot
sns.boxplot(data=data['Rating'])

# %%
#remover catagorical variables
# data_int = data.drop(['Titulo', 'Autor', 'Genero'], axis=1)
#seleccionar variables para box plot
# data_num = data.drop(['Titulo', 'Autor', 'Genero', "FechaLanzamiento"], axis=1)
#plot boxplot
# sns.boxplot(data=data_num["Reviews"])
sns.boxplot(data=data_num["Precio"])

# %%
# data_int = data.drop(['Titulo', 'Autor', 'Genero'], axis=1)
data_num = [x for x in data.columns if data[x].dtype!="object" and data[x].dtype!="datetime64[ns]"]
data_num

# %%
numeric_features=[x for x in data.columns if data[x].dtype!="object"]
#taking only the numeric columns from the dataframe.

for i in data[numeric_features].columns:
    plt.figure(figsize=(12,5))
    plt.title(i)
    sns.boxplot(data=data[i])

# https://stackoverflow.com/questions/19189488/use-a-loop-to-plot-n-charts-python
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-8c88f971de52> in <module>
# ----> 1 numeric_features=[x for x in data.columns if data[x].dtype!="object"]
#       2 #taking only the numeric columns from the dataframe.
#       3
#       4 for i in data[numeric_features].columns:
#       5     plt.figure(figsize=(12,5))
#
# NameError: name 'data' is not defined

# %%
plt.scatter(data.Rating, data.Reviews, c='green')
plt.xlabel('Rating')
plt.ylabel('Reviews')
plt.suptitle('Relación entre Rating y reviews')

# %%
plt.scatter(data['Rating'], data.Precio, c='red')
plt.xlabel('Rating')
plt.ylabel('Precio')

# %%
print(__doc__)


# Code source: Jaques Grobler
# License: BSD 3 clause


import matplotlib.pyplot as plt
import numpy as np
from sklearn import datasets, linear_model
from sklearn.metrics import mean_squared_error, r2_score

# Load the diabetes dataset
diabetes_X, diabetes_y = datasets.load_diabetes(return_X_y=True)

# Use only one feature
diabetes_X = diabetes_X[:, np.newaxis, 2]

# Split the data into training/testing sets
diabetes_X_train = diabetes_X[:-20]
diabetes_X_test = diabetes_X[-20:]

# Split the targets into training/testing sets
diabetes_y_train = diabetes_y[:-20]
diabetes_y_test = diabetes_y[-20:]

# Create linear regression object
regr = linear_model.LinearRegression()

# Train the model using the training sets
regr.fit(diabetes_X_train, diabetes_y_train)

# Make predictions using the testing set
diabetes_y_pred = regr.predict(diabetes_X_test)

# The coefficients
print('Coefficients: \n', regr.coef_)
# The mean squared error
print('Mean squared error: %.2f'
      % mean_squared_error(diabetes_y_test, diabetes_y_pred))
# The coefficient of determination: 1 is perfect prediction
print('Coefficient of determination: %.2f'
      % r2_score(diabetes_y_test, diabetes_y_pred))

# Plot outputs
plt.scatter(diabetes_X_test, diabetes_y_test,  color='black')
plt.plot(diabetes_X_test, diabetes_y_pred, color='blue', linewidth=3)

plt.xticks(())
plt.yticks(())

plt.show()
# Out:
# Automatically created module for IPython interactive environment
# Coefficients:
#  [938.23786125]
# Mean squared error: 2548.07
# Coefficient of determination: 0.47

# %%
diabetes_X_train
# Out:
# array([[ 0.06169621],
#        [-0.05147406],
#        [ 0.04445121],
#        [-0.01159501],
#        [-0.03638469],
#        [-0.04069594],
#        [-0.04716281],
#        [-0.00189471],
#        [ 0.06169621],
#        [ 0.03906215],
#        [-0.08380842],
#        [ 0.01750591],
#        [-0.02884001],
#        [-0.00189471],
#        [-0.02560657],
#        [-0.01806189],
#        [ 0.04229559],
#        [ 0.01211685],
#        [-0.0105172 ],
#        [-0.01806189],
#        [-0.05686312],
#        [-0.02237314],
#        [-0.00405033],
#        [ 0.06061839],
#        [ 0.03582872],
#        [-0.01267283],
#        [-0.07734155],
#        [ 0.05954058],
#        [-0.02129532],
#        [-0.00620595],
#        [ 0.04445121],
#        [-0.06548562],
#        [ 0.12528712],
#        [-0.05039625],
#        [-0.06332999],
#        [-0.03099563],
#        [ 0.02289497],
#        [ 0.01103904],
#        [ 0.07139652],
#        [ 0.01427248],
#        [-0.00836158],
# ...

# %%
#Pairplots 
# https://towardsdatascience.com/visualizing-data-with-pair-plots-in-python-f228cf529166

# %%
#Variable encoding
data = pd.DataFrame(pd.get_dummies(data, columns=["Genero"]))
data.head()

# %% [markdown]
# Unir el dataset original con la cuenta de libros por autor
# https://stackoverflow.com/questions/35809098/how-to-merge-pandas-value-counts-to-dataframe-or-use-it-to-subset-a-dataframe

# %%
data = data.join(pd.DataFrame(encoder_results.toarray(), columns=encoder.categories_))
data.head()

# %%
#crear la cuenta total de libros por autor
autor = data['Autor'].value_counts()
autor.head()

# %%
test = {'Precio':[10,8,4,56,9,8], 
        'unidad':[ 1, 23, 47, 96, 5, 22]} 
test = pd.DataFrame(test)
test['Ganancia'] = test.Precio * test.unidad
# test['promedio'] = test.Ganancia.sum() / len(test.Ganancia)
print(test.Ganancia.sum())
test['promedio']=(test['Ganancia'] * 100) / test.Ganancia.sum()
test

# %%
pip install notebook-as-pdf
# pyppeteer-install
# Out:
#   File "<ipython-input-16-e1ece1ef8d4c>", line 1
#     pip install notebook-as-pdf
#               ^
# SyntaxError: invalid syntax

# %%
nbconvert --to pdf notebook.ipynb
# Out:
#   File "<ipython-input-12-7203f9a2008b>", line 1
#     nbconvert --to pdf notebook.ipynb
#                      ^
# SyntaxError: invalid syntax

# %% [markdown]
# https://towardsdatascience.com/classification-basics-walk-through-with-the-iris-data-set-d46b0331bf82
#
# https://medium.com/@harimittapalli/exploratory-data-analysis-iris-dataset-9920ea439a3e
